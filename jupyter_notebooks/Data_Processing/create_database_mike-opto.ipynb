# %%
import sys
sys.path.append('/Users/Sabatini Lab/GitHub/mouse_bandit/data_preprocessing_code/opto_preprocessing')
sys.path.append('/Users/Sabatini Lab/GitHub/mouse_bandit')
import support_functions as sf
import numpy as np
import pandas as pd
import scipy as sp
import bandit_preprocessing_opto as bp
import sys
import os
import behavior_database_opto as behavior_database

# %% [markdown]
# ## load in database (never save the db using excel it messes with date formatting!)

# %%
record_df = pd.read_csv('/Users/Sabatini Lab/GitHub/mouse_bandit/session_record.csv',index_col=0)

# %%
record_df.shape
# Out:
# (1205, 18)

# %% [markdown]
# ### First time we ran this, had to add 'shay' to the old data base
# aka we did:
# ```record_df.insert(0,'Owner','shay') and laser stim prob record_df.insert(5,'Laser Stim Prob',0)```

# %%
record_df.tail(10)
# Out:
#      Owner      Session ID Mouse ID                 Date  Phase  \
# 1195  mike  08252017_SOM40    SOM40  2017-08-25 00:00:00      1
# 1196  mike  08252017_SOM41    SOM41  2017-08-25 00:00:00      2
# 1197  mike  08252017_SOM44    SOM44  2017-08-25 00:00:00      2
# 1198  mike  08252017_SOM45    SOM45  2017-08-25 00:00:00      2
# 1199  mike   08282017_PV27     PV27  2017-08-28 00:00:00      2
# 1200  mike   08282017_PV31     PV31  2017-08-28 00:00:00      2
# 1201  mike  08282017_SOM40    SOM40  2017-08-28 00:00:00      1
# 1202  mike  08282017_SOM41    SOM41  2017-08-28 00:00:00      2
# 1203  mike  08282017_SOM44    SOM44  2017-08-28 00:00:00      2
# 1204  mike  08282017_SOM45    SOM45  2017-08-28 00:00:00      2
#
#       Laser Stim Prob  Left Reward Prob  Right Reward Prob  Block Range Min  \
# 1195              0.0               1.0                1.0             1000
# 1196              0.1               0.7                0.3               50
# ...

# %% [markdown]
# ## Add single day (multi mice)

# %%
DAY = '09012017'
ROOT = '/Users/Sabatini Lab/Dropbox (HMS)/Mike_BehaviorFiles/'
root_day = os.path.join(ROOT,DAY)

mouse_folders = os.listdir(root_day)

for mouse in mouse_folders:
    if not mouse[0] == '.':
        curr_dir = os.path.join(root_day,mouse)

        record_df = behavior_database.add_session(curr_dir,record_df,'mike')

# %%
mouse_folders
# Out:
# ['PV27', 'PV31', 'SOM40', 'SOM41', 'SOM44', 'SOM45']

# %%
record_df.tail(10)
# Out:
#      Owner      Session ID Mouse ID                 Date  Phase  \
# 1219  mike  08312017_SOM40    SOM40  2017-08-31 00:00:00      2
# 1220  mike  08312017_SOM41    SOM41  2017-08-31 00:00:00      2
# 1221  mike  08312017_SOM44    SOM44  2017-08-31 00:00:00      2
# 1222  mike  08312017_SOM45    SOM45  2017-08-31 00:00:00      2
# 1223  mike   09012017_PV27     PV27  2017-09-01 00:00:00      2
# 1224  mike   09012017_PV31     PV31  2017-09-01 00:00:00      2
# 1225  mike  09012017_SOM40    SOM40  2017-09-01 00:00:00      2
# 1226  mike  09012017_SOM41    SOM41  2017-09-01 00:00:00      2
# 1227  mike  09012017_SOM44    SOM44  2017-09-01 00:00:00      2
# 1228  mike  09012017_SOM45    SOM45  2017-09-01 00:00:00      2
#
#       Laser Stim Prob  Left Reward Prob  Right Reward Prob  Block Range Min  \
# 1219              0.0               0.8                0.2               50
# 1220              0.0               0.7                0.3               50
# ...

# %%
mike_record = record_df[record_df['Owner']=='mike'].copy()

# %%
mike_record.tail(10)
# Out:
#      Owner      Session ID Mouse ID                 Date  Phase  \
# 1219  mike  08312017_SOM40    SOM40  2017-08-31 00:00:00      2
# 1220  mike  08312017_SOM41    SOM41  2017-08-31 00:00:00      2
# 1221  mike  08312017_SOM44    SOM44  2017-08-31 00:00:00      2
# 1222  mike  08312017_SOM45    SOM45  2017-08-31 00:00:00      2
# 1223  mike   09012017_PV27     PV27  2017-09-01 00:00:00      2
# 1224  mike   09012017_PV31     PV31  2017-09-01 00:00:00      2
# 1225  mike  09012017_SOM40    SOM40  2017-09-01 00:00:00      2
# 1226  mike  09012017_SOM41    SOM41  2017-09-01 00:00:00      2
# 1227  mike  09012017_SOM44    SOM44  2017-09-01 00:00:00      2
# 1228  mike  09012017_SOM45    SOM45  2017-09-01 00:00:00      2
#
#       Laser Stim Prob  Left Reward Prob  Right Reward Prob  Block Range Min  \
# 1219              0.0               0.8                0.2               50
# 1220              0.0               0.7                0.3               50
# ...

# %% [markdown]
# # save (overwrite) session_record

# %%
record_df.to_csv(path_or_buf='/Users/Sabatini Lab/GitHub/mouse_bandit/session_record.csv')

# %%
mike_record.to_csv(path_or_buf='/Users/Sabatini Lab/GitHub/mouse_bandit/mike_session_record.csv')
