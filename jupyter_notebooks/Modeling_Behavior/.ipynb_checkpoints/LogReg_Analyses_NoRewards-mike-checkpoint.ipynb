# %% [markdown]
# # Logistic Regression
#
# This logistic regression is based on the Beeler/Daw et al. 2010 paper.
# Specifically:
#
# dependent variable: binary choice of port (-1 or 1)
#
# explanatory variables:
# 1. the N previous rewards $ r_{t-N:t-1} $
# 2. the previous choice $c_{t-1}$ to capture a tendency to stay or switch
# 3. bias variable (1) to capture fixed, overall preference for either port
#
# Note: this model only carries information about ports when it gets a reward. IE -1 = right reward, 1 = left reward, but 0 = no reward (for either side). Should compare models with this information vs. added information about the non-rewarded port choices.

# %% [markdown]
# ## 08/22/2017
# I just ran the above code on the following data:
#
# - `all_9010_high_processed.csv`
#
# Which were computed by compiling the following data:
# - block range: exactly 50 rewards
# - p(choose high Port) >= [p-0.1] where p = p(high Port)
#
# Shay's Observations:
# 1. pseudo-R2 also similar: ~0.64-0.69
# 2. For (1)  maybe a slight trend that 90-10 had a better model, but not certain.
# 3. For each condition, I tried adding in more ports (up to 3) into the past to see if it would help out. For all 3 conditions, decisions for t-N where 2 >= 2 had coefficients = 0. That is, the only non-zero beta for the ports was the most recent one.
#
# Next step:
#
#
# **Figures**
#
# 1. Logistic regression performs similarly across different conditions
#     - x axis: 90-10,80-20,70-30
#     - y axis: F1 score, pseudo-R2
# 2. Comparing model flexibility across different conditions
#     - x axis: number of previous rewards included (i.e. parameters in model)
#     - y axis: BIC
#     - color: each condition
# 3. Knowing where the non-rewarded trials are:
#     - what if you did the same regression, but instead you know where the non-rewarded trials are?
#     - also, compare to adding in previous ports (or rewards in the above scenario) and compare
#
# 4. Comparing 'strategies' across conditions
#     - train on 90-10, test on 80-20 (and all combinations)
#
# 5. Comparing 'strategies' across mice
#     - train on one mouse:condition pair, and test on another mouse:condition pair (for the same condition)

# %%
import sys
sys.path.append('/Users/Sabatini Lab/GitHub/mouse_bandit/data_preprocessing_code')
sys.path.append('/Users/Sabatini Lab/GitHub/mouse_bandit')
import support_functions as sf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import pandas as pd
import scipy as sp
import bandit_preprocessing as bp
import sklearn.linear_model
import sklearn.tree
import statsmodels
# %matplotlib inline

# %% [markdown]
# ## define function to do logistic regression and some basic evalutions

# %%
'''
I compiled the code above into a more compact function so I can cycle through different conditions/mice/etc 
as neccessary
'''

def logreg_and_eval(data,num_rewards=10,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix)
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix and INVERT THE REWARDS
    #so here -1 --> NO REWARD on the right side
    # and 1--> NO REWARD on the left side
    # and 0 --> Reward on either side
    d = data.copy()
    for i in range(len(port_features)):
        inv_rewards = np.abs(d[reward_features[i]].values - 1)
        d[reward_features[i]] = inv_rewards*d[port_features[i]].values
    
    
    #determine the features
    features = reward_features.copy()
    features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    features.append('1_Port') #append the last decision as a feature
    features.append('Decision') #finally append the decision so we can take it to predict later
    
    #final version of data
    d = d[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            inv_rewards = np.abs(data_test_new[reward_features[i]].values - 1)
            data_test_new[reward_features[i]] = inv_rewards*test_data[port_features[i]].values
        
        d_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = d.iloc[:,:-1].values
        y_train = d.iloc[:,-1].values
        x_test = d_test.iloc[:,:-1].values
        y_test = d_test.iloc[:,-1].values
        
        prev_port_test = d_test['1_Port'].values
        prev_port_test[prev_port_test==-1] = 0
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = d.iloc[:,:-1].values
        y = d.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
        
        #extract previous port decision for test set
        #these will be used to calculate switches on the test predictions
        prev_port_test = d['1_Port'].values[shuf_inds[split_ind:]]
        prev_port_test[prev_port_test==-1] = 0
    
    '''
    Modeling
    '''
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #switches
    y_test_switch = np.abs(y_test - prev_port_test)
    y_predict_switch = np.abs(y_predict - prev_port_test)
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d_ = {'pseudo-R2':rslt.prsquared,'F1':F1,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d_,index=[0])
    features = features[:-1]
    features.append('Bias')
    
    coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
    return logreg,stats,coefs

# %%
def logreg_and_eval_withports(data,num_rewards=10,num_ports=1,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix)
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix
    d = data.copy()
    for i in range(len(port_features)):
        inv_rewards = np.abs(d[reward_features[i]].values - 1)
        d[reward_features[i]] = inv_rewards*d[port_features[i]].values
    
    #determine the features
    features = reward_features.copy()
    if num_rewards == 0:
        features = port_features[-1*num_ports:]
    elif num_ports == 0:
        features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    else:
        features = features[-1*num_rewards:]
        features = np.append(features,port_features[-1*num_ports:])
    
    print(features)
    features = np.append(features,'Decision') #finally append the decision so we can take it to predict later
    
    
    
    #final version of data
    d = d[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            inv_rewards = np.abs(data_test_new[reward_features[i]].values - 1)
            data_test_new[reward_features[i]] = inv_rewards*test_data[port_features[i]].values
        
        d_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = d.iloc[:,:-1].values
        y_train = d.iloc[:,-1].values
        x_test = d_test.iloc[:,:-1].values
        y_test = d_test.iloc[:,-1].values
        
        prev_port_test = test_data['1_Port'].values
        prev_port_test[prev_port_test==-1] = 0
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = d.iloc[:,:-1].values
        y = d.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
        
        #extract previous port decision for test set
        #these will be used to calculate switches on the test predictions
        prev_port_test = data['1_Port'].values[shuf_inds[split_ind:]]
        prev_port_test[prev_port_test==-1] = 0
    
    '''
    Modeling
    '''
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #switches
    y_test_switch = np.abs(y_test - prev_port_test)
    y_predict_switch = np.abs(y_predict - prev_port_test)
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d_ = {'pseudo-R2':rslt.prsquared,'F1':F1,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d_,index=[0])
    features = features[:-1]
    features = np.append(features,'Bias')
    
    coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
    return logreg,stats,coefs

# %% [markdown]
# # Write here

# %%
data_90 = pd.read_csv('/Users/Sabatini Lab/GitHub/mouse_bandit/data/mike_data/trial_data/all_9010_high_processed2.csv',index_col=0)
#data_80 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_8020_02192017.csv',index_col=0)
#data_70 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_7030_02192017.csv',index_col=0)

datas = [data_90]
models = []

# %%
for i,d in enumerate(datas):
    
    for j in range(30):
        model_curr,stats_curr,coefs_curr = logreg_and_eval(d,num_rewards=7)
        models.append(models)

        if ((i == 0 and j == 0)):
            stats = stats_curr.copy()
            coefs = coefs_curr.copy()
        else:
            stats = stats.append(stats_curr)
            coefs = coefs.append(coefs_curr)

c = np.zeros(30)+90


stats.insert(0,'Condition',c)
coefs.insert(0,'Condition',c)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.251034
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13782.0            0.0
# True YES        1346.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.245836
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13672.0            0.0
# True YES        1456.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250782
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13758.0            0.0
# True YES        1370.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250142
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13731.0            0.0
# True YES        1397.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248799
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13718.0            0.0
# True YES        1410.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251295
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13741.0            0.0
# True YES        1387.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249628
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13739.0            0.0
# True YES        1389.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13774.0            0.0
# True YES        1354.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249668
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13738.0            0.0
# True YES        1390.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.246992
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13698.0            0.0
# True YES        1430.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249924
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13744.0            0.0
# True YES        1384.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250831
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13734.0            0.0
# True YES        1394.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.246884
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13703.0            0.0
# True YES        1425.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251008
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13742.0            0.0
# True YES        1386.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250882
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13771.0            0.0
# True YES        1357.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248782
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13695.0            0.0
# True YES        1433.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251910
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13761.0            0.0
# True YES        1367.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249747
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13725.0            0.0
# True YES        1403.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251127
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13772.0            0.0
# True YES        1356.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.245793
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13674.0            0.0
# True YES        1454.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249421
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13750.0            0.0
# True YES        1378.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.252727
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13753.0            0.0
# True YES        1375.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250098
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13713.0            0.0
# True YES        1415.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248919
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13705.0            0.0
# True YES        1423.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247990
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13689.0            0.0
# True YES        1439.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247032
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13692.0            0.0
# True YES        1436.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250403
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13738.0            0.0
# True YES        1390.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250743
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13700.0            0.0
# True YES        1428.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248304
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13705.0            0.0
# True YES        1423.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251826
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13765.0            0.0
# True YES        1363.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00

# %% [markdown]
# # Comparing beta coefficients across conditions

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,4))
gs = gridspec.GridSpec(1,4,width_ratios=[2,1,1,1])

plt.subplot(gs[0])
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='red',alpha=0.5)
#plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
 #            yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
   #          color='green',alpha=0.5)
#plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
 #            yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
  #           color='navy',alpha=0.5)

plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
            color='red',label='90-10',s=50)
#plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
 #           color='green',label='80-20',s=50)
#plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
 #           color='navy',label='70-30',s=50)

plt.legend(loc='upper left')
plt.xticks(np.arange(coefs.shape[1]),coefs.columns.values[1:],rotation='vertical')
plt.xlim(-0.5,8.5)
plt.title('Regression Coefficients')

plt.subplot(gs[1])
sns.barplot(x='Condition',y='Accuracy',data=stats)
plt.title('Accuracy (test)')
plt.xticks([0],['90'],fontsize=20)
plt.yticks([0.7,0.8,0.9,1.0],fontsize=20)
plt.xlabel('Condition',fontsize=20)
plt.ylim(0.7,1)

plt.subplot(gs[2])
sns.barplot(x='Condition',y='F1',data=stats)
plt.title('F1 (test)')



plt.subplot(gs[3])
sns.barplot(x='Condition',y='pseudo-R2',data=stats)
plt.title('pseudo-R2')
plt.ylim(0.5,0.8)

plt.tight_layout()

# %% [markdown]
# ## Test number of parameters / model flexibility vs BIC

# %%
stats.head(2)
# Out:
#    Condition  Accuracy           BIC  F1  negative loglikelihood  pseudo-R2
# 0       90.0  0.905870  17553.867992   0             8735.047783   0.642738
# 0       90.0  0.906068  17556.845902   0             8736.536738   0.642737

# %%
d = data_90.copy()
stats = pd.DataFrame(columns=['Accuracy','BIC','negative loglikelihood','pseudo-R2','No. parameters'])

for i,n in enumerate(np.arange(10,0,-1)):
    
    for j in enumerate(range(30)):
        model_curr,stats_curr,coefs_curr = logreg_and_eval(d,num_rewards=n)
        models.append(models)
        stats_curr['No. parameters'] = n
        stats = stats.append(stats_curr)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.253069
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13786.0            0.0
# True YES        1342.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248977
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13751.0            0.0
# True YES        1377.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249736
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13715.0            0.0
# True YES        1413.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250484
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13739.0            0.0
# True YES        1389.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248302
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13672.0            0.0
# True YES        1456.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250631
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13736.0            0.0
# True YES        1392.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247796
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13679.0            0.0
# True YES        1449.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251606
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13759.0            0.0
# True YES        1369.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251173
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13771.0            0.0
# True YES        1357.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248882
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13715.0            0.0
# True YES        1413.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248455
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13710.0            0.0
# True YES        1418.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250239
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13725.0            0.0
# True YES        1403.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248813
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13707.0            0.0
# True YES        1421.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.252268
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13784.0            0.0
# True YES        1344.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247430
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13701.0            0.0
# True YES        1427.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249699
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13705.0            0.0
# True YES        1423.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251029
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13750.0            0.0
# True YES        1378.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248535
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13730.0            0.0
# True YES        1398.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250995
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13744.0            0.0
# True YES        1384.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250289
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13717.0            0.0
# True YES        1411.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250749
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13720.0            0.0
# True YES        1408.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250861
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13750.0            0.0
# True YES        1378.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251124
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13776.0            0.0
# True YES        1352.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251200
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13748.0            0.0
# True YES        1380.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250418
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13744.0            0.0
# True YES        1384.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250934
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13759.0            0.0
# True YES        1369.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247097
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13711.0            0.0
# True YES        1417.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249334
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13728.0            0.0
# True YES        1400.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248828
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13722.0            0.0
# True YES        1406.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250548
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13756.0            0.0
# True YES        1372.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
# Optimization terminated successfully.
#          Current function value: 0.249506
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13720.0            0.0
# True YES        1408.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247513
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13706.0            0.0
# True YES        1422.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249795
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13739.0            0.0
# True YES        1389.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249635
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13745.0            0.0
# True YES        1383.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247445
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13690.0            0.0
# True YES        1438.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250169
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13720.0            0.0
# True YES        1408.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.253055
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13790.0            0.0
# True YES        1338.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249366
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13742.0            0.0
# True YES        1386.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.253578
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13808.0            0.0
# True YES        1320.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.252039
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13774.0            0.0
# True YES        1354.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247048
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13701.0            0.0
# True YES        1427.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250421
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13762.0            0.0
# True YES        1366.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247477
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13683.0            0.0
# True YES        1445.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249208
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13739.0            0.0
# True YES        1389.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251124
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13739.0            0.0
# True YES        1389.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248222
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13696.0            0.0
# True YES        1432.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250134
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13730.0            0.0
# True YES        1398.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251128
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13761.0            0.0
# True YES        1367.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.252254
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13754.0            0.0
# True YES        1374.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.252234
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13767.0            0.0
# True YES        1361.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247542
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        
0            0.0
# True YES        1399.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249794
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13716.0            0.0
# True YES        1412.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251029
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13738.0            0.0
# True YES        1390.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
# Optimization terminated successfully.
#          Current function value: 0.248377
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13729.0            0.0
# True YES        1399.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251896
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13764.0            0.0
# True YES        1364.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247567
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13704.0            0.0
# True YES        1424.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251578
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13738.0            0.0
# True YES        1390.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249810
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13728.0            0.0
# True YES        1400.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250582
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13734.0            0.0
# True YES        1394.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247786
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13666.0            0.0
# True YES        1462.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249388
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13752.0            0.0
# True YES        1376.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247677
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13692.0            0.0
# True YES        1436.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249919
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13727.0            0.0
# True YES        1401.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250481
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13711.0            0.0
# True YES        1417.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247216
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13687.0            0.0
# True YES        1441.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250234
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13709.0            0.0
# True YES        1419.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.246748
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13672.0            0.0
# True YES        1456.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.254361
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13786.0            0.0
# True YES        1342.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249948
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13706.0            0.0
# True YES        1422.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248867
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13705.0            0.0
# True YES        1423.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251656
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13766.0            0.0
# True YES        1362.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249974
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13693.0            0.0
# True YES        1435.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250109
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13733.0            0.0
# True YES        1395.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249793
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13729.0            0.0
# True YES        1399.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249399
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13727.0            0.0
# True YES        1401.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251154
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13761.0            0.0
# True YES        1367.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.250139
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13741.0            0.0
# True YES        1387.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.247449
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13690.0            0.0
# True YES        1438.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.252753
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13772.0            0.0
# True YES        1356.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251038
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13726.0            0.0
# True YES        1402.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.249326
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13715.0            0.0
# True YES        1413.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.248849
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13725.0            0.0
# True YES        1403.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251935
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13760.0            0.0
# True YES        1368.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00

# %%
plt.figure(figsize=(10,4))
sns.factorplot(x='No. parameters',y='BIC',data=stats,color='black')
plt.title('BIC vs model flexibility')

# %%
BIC = np.zeros((10,10))
F1 = np.zeros((10,10))
R2 = np.zeros((10,10))
acc = np.zeros((10,10))

for i in range(10):
    for j in range(10):
        if not ((j==0) & (i==0)):
            model_curr,stats_curr,coefs_curr = logreg_and_eval_withports(d,num_rewards=i,num_ports=j)
            BIC[i,j] = stats_curr['BIC'].values
            F1[i,j] = stats_curr['F1'].values
            R2[i,j] = stats_curr['pseudo-R2'].values
            acc[i,j] = stats_curr['Accuracy'].values
# Out:
# ['1_Port']
# Optimization terminated successfully.
#          Current function value: 0.308868
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13747.0            0.0
# True YES        1381.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.291305
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13722.0            0.0
# True YES        1406.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.285591
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13715.0            0.0
# True YES        1413.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.285453
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13780.0            0.0
# True YES        1348.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.282625
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13734.0            0.0
# True YES        1394.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.281685
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13744.0            0.0
# True YES        1384.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.281226
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13726.0            0.0
# True YES        1402.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['8_Port', '7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.284582
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13810.0            0.0
# True YES        1318.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['9_Port', '8_Port', '7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.279031
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13714.0            0.0
# True YES        1414.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.674193
#          Iterations 5
#           Predicted NO  Predicted YES
# True NO         8109.0         5584.0
# True YES        1203.0          232.0
#
# F1: 0.064
#
# Accuracy on class 0: 0.59
# Accuracy on class 1: 0.16
#
# ['1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248397
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13701.0            0.0
# True YES        1427.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.241573
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13436.0          291.0
# True YES        1072.0          329.0
#
# F1: 0.326
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.23
#
# ['1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.239968
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13555.0          204.0
# True YES        1123.0          246.0
#
# F1: 0.270
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.18
#
# ['1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.237809
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13504.0          194.0
# True YES        1193.0          237.0
#
# F1: 0.255
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.17
#
# ['1_Reward' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.239761
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13528.0          201.0
# True YES        1115.0          284.0
#
# F1: 0.301
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.20
#
# ['9_Reward', '8_Reward', '7_Reward', '6_Reward', '5_Reward', '4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.669626
#          Iterations 5
#           Predicted NO  Predicted YES
# True NO         8774.0         4980.0
# True YES        1152.0          222.0
#
# F1: 0.068
#
# Accuracy on class 0: 0.64
# Accuracy on class 1: 0.16
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247315
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13677.0            0.0
# True YES        1451.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.238999
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13596.0          164.0
# True YES        1182.0          186.0
#
# F1: 0.217
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.14
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.235066
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13550.0          205.0
# True YES        1152.0          221.0
#
# F1: 0.246
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.16
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.231547
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13494.0          225.0
# True YES        1141.0          268.0
#
# F1: 0.282
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.232366
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13483.0          244.0
# True YES        1115.0          286.0
#
# F1: 0.296
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.20
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.233111
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13514.0          236.0
# True YES        1116.0          262.0
#
# F1: 0.279
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.230297
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13474.0          222.0
# True YES        1153.0          279.0
#
# F1: 0.289
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.230115
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13450.0          224.0
# True YES        1172.0          282.0
#
# F1: 0.288
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port'
#  '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.232051
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        13491.0          229.0
# True YES        1113.0          295.0
#
# F1: 0.305
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.21

# %%
plt.figure(figsize=(20,5))
plt.suptitle('Model behavior vs # of rewards and decisions included',x=0.5,y=1.05,fontsize=20)

plt.subplot(141)
sns.heatmap(BIC,vmin=15000,vmax=25000)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('BIC',fontsize=15)

plt.subplot(142)
sns.heatmap(F1)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('F1',fontsize=15)

plt.subplot(143)
sns.heatmap(R2,vmin=0.5)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('R2')

plt.subplot(144)
sns.heatmap(acc,vmin=0.8)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('Accuracy')

plt.tight_layout()

# %% [markdown]
# ## END

# %% [markdown]
# # Training / testing on different conditions

# %% [markdown]
# ### 1. Train on 90-10, test on 80-20 and 70-30

# %%
for i,d in enumerate([data_90,data_80,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_90,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_90 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.231716
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2969.0            0.0
# True YES         267.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.232174
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        23217.0        20744.0
# True YES        2496.0         2388.0
#
# F1: 0.170
#
# Accuracy on class 0: 0.53
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.232174
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         8226.0         7987.0
# True YES         842.0          801.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.49

# %%
stats_90['Testing Condition'] = [90,80,70]
stats_90
# Out:
#    Accuracy        F1  Testing Condition
# 0  0.917491  0.000000                 90
# 0  0.524209  0.170474                 80
# 0  0.505544  0.153581                 70

# %% [markdown]
# So this is interesting - accuracy stays pretty much the same across conditions, but F1 goes way down. And if we take a look at the confusion tables above, we can see it is because the accuracy on the switches went down (and accuracy on stays went up.

# %% [markdown]
# ### 2. Train on 80-20

# %%
for i,d in enumerate([data_80,data_90,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_80,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_80 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_80['Testing Condition'] = [80,90,70]
stats_80
# Out:
# Optimization terminated successfully.
#          Current function value: 0.260729
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13145.0            0.0
# True YES        1509.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263445
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5952.0         3923.0
# True YES         624.0          287.0
#
# F1: 0.112
#
# Accuracy on class 0: 0.60
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.263445
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12138.0         4075.0
# True YES        1240.0          403.0
#
# F1: 0.132
#
# Accuracy on class 0: 0.75
# Accuracy on class 1: 0.25
#    Accuracy        F1  Testing Condition
# 0  0.897025  0.000000                 80
# 0  0.578435  0.112087                 90
# 0  0.702341  0.131678                 70

# %% [markdown]
# ### 3. Train on 70-30

# %%
for i,d in enumerate([data_70,data_80,data_90]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_70,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_70 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_70['Testing Condition'] = [70,80,90]
stats_70
# Out:
# Optimization terminated successfully.
#          Current function value: 0.255697
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4866.0            0.0
# True YES         491.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.256850
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        37114.0         6847.0
# True YES        3739.0         1145.0
#
# F1: 0.178
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.256850
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         8343.0         1532.0
# True YES         699.0          212.0
#
# F1: 0.160
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.23
#    Accuracy        F1  Testing Condition
# 0  0.908344  0.000000                 70
# 0  0.783274  0.177850                 80
# 0  0.793158  0.159699                 90

# %%
f1s = np.vstack((stats_90['F1'].values,
               stats_80['F1'].values[[1,0,2]],
               stats_70['F1'].values[[2,1,0]]))
sns.heatmap(f1s)
plt.xticks([0.5,1.5,2.5],['90','80','70'])
plt.yticks([0.5,1.5,2.5],['70','80','90'])
plt.ylabel('Testing Condition')
plt.xlabel('Training Condition')
plt.title('F1 scores when trained & tested on different conditions')

# %% [markdown]
# So if this is right, it means that the rules are different - what predicts a switch in 90-10 does not predict a switch in 80-20. But since most of the trials follow the last one, the accuracy doesn't drop very much. So it appears to be working fine, even though it is not.
#
# Can the difference be explained in the small differences in beta coefficient values? It must be ... what else is there? They seem similar enough that I'm surprised it makes such a difference.
#
# Let's go on to train and test on separate mice:

# %% [markdown]
# # Train/test on separate mice

# %% [markdown]
# First let's take a quick look at the mice's performances - specifically just at p(choose high P port):

# %%
data_90.insert(0,'Condition',0.9)
data_80.insert(0,'Condition',0.8)
data_70.insert(0,'Condition',0.7)

# %%
all_data = data_90.append(data_80)
all_data = all_data.append(data_70)
all_data.shape
# Out:
# (77487, 51)

# %%
sns.factorplot(x='Condition',y='Higher p port',hue='Mouse ID',data = all_data,legend=False,size=5,aspect=1.7)
plt.legend(bbox_to_anchor=(1.2,1))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Condition',fontsize=20)
plt.ylabel('rate higher prob port chosen',fontsize=20)
plt.title('Average p(choose better port) for each mouse across conditions',fontsize=20,x=0.5,y=1.1)

# %% [markdown]
# Okay, so based on this. Let's start with 80-20, and do a few different comparisons.
#
# 1. Start by training with harry, and testing on all the others.
# 2. Then try training on volde, testing on all others.
# 3. Finally train on someone in the middle - like Tom or q45, and test on others

# %%
'''
Loop through mice
'''
mice = np.unique(data_80['Mouse ID'].values)

stats = pd.DataFrame(columns=['Accuracy','F1','Training Mouse','Testing Mouse'])
test_mice = []
train_mice = []

for mouse_train in mice:

    d_train = data_80[data_80['Mouse ID'] == mouse_train].copy()

    for i,mouse_test in enumerate(mice):
        d_test = data_80[data_80['Mouse ID'] == mouse_test].copy()

        if i == 0:
            model,stats_curr,coefs = logreg_and_eval(d_train,test_data = d_test)
            stats_curr = stats_curr.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
            stats = stats.append(stats_curr)
        else:
            model,stats_curr,coefs_curr = logreg_and_eval(d_train,test_data = d_test)
            stats_curr = stats_curr.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
            stats= stats.append(stats_curr)
            coefs = coefs.append(coefs_curr)

        test_mice.append(mouse_test)
        train_mice.append(mouse_train)

stats['Testing Mouse'] = test_mice
stats['Training Mouse'] = train_mice
acc_matrix = np.reshape(stats['Accuracy'].values,(len(mice),-1)).T
F1_matrix = np.reshape(stats['F1'].values,(len(mice),-1)).T
# Out:
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          211.0          128.0
# True YES          41.0           40.0
#
# F1: 0.321
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3135.0         2869.0
# True YES         297.0          292.0
#
# F1: 0.156
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3472.0         2848.0
# True YES         226.0          218.0
#
# F1: 0.124
#
# Accuracy on class 0: 0.55
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          511.0          751.0
# True YES          66.0           68.0
#
# F1: 0.143
#
# Accuracy on class 0: 0.40
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3777.0         3365.0
# True YES         338.0          330.0
#
# F1: 0.151
#
# Accuracy on class 0: 0.53
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          515.0          562.0
# True YES          90.0           91.0
#
# F1: 0.218
#
# Accuracy on class 0: 0.48
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2639.0         2554.0
# True YES         224.0          221.0
#
# F1: 0.137
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2634.0         1992.0
# True YES         437.0          427.0
#
# F1: 0.260
#
# Accuracy on class 0: 0.57
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2160.0         1681.0
# True YES         216.0          211.0
#
# F1: 0.182
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2744.0         2565.0
# True YES         288.0          279.0
#
# F1: 0.164
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1744.0         1104.0
# True YES         243.0          241.0
#
# F1: 0.264
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          229.0          110.0
# True YES          48.0           33.0
#
# F1: 0.295
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3734.0         2270.0
# True YES         439.0          150.0
#
# F1: 0.100
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4000.0         2320.0
# True YES         328.0          116.0
#
# F1: 0.081
#
# Accuracy on class 0: 0.63
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          728.0          534.0
# True YES          98.0           36.0
#
# F1: 0.102
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4486.0         2656.0
# True YES         501.0          167.0
#
# F1: 0.096
#
# Accuracy on class 0: 0.63
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          626.0          451.0
# True YES         131.0           50.0
#
# F1: 0.147
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3202.0         1991.0
# True YES         361.0           84.0
#
# F1: 0.067
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2883.0         1743.0
# True YES         571.0          293.0
#
# F1: 0.202
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.34
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2444.0         1397.0
# True YES         306.0          121.0
#
# F1: 0.124
#
# Accuracy on class 0: 0.64
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3216.0         2093.0
# True YES         429.0          138.0
#
# F1: 0.099
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1873.0          975.0
# True YES         304.0          180.0
#
# F1: 0.220
#
# Accuracy on class 0: 0.66
# Accuracy on class 1: 0.37
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          241.0           98.0
# True YES          51.0           30.0
#
# F1: 0.287
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.37
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4428.0         1576.0
# True YES         452.0          137.0
#
# F1: 0.119
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4706.0         1614.0
# True YES         342.0          102.0
#
# F1: 0.094
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          919.0          343.0
# True YES         101.0           33.0
#
# F1: 0.129
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         5210.0         1932.0
# True YES         525.0          143.0
#
# F1: 0.104
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          733.0          344.0
# True YES         139.0           42.0
#
# F1: 0.148
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3826.0         1367.0
# True YES         375.0           70.0
#
# F1: 0.074
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3146.0         1480.0
# True YES         597.0          267.0
#
# F1: 0.205
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         2752.0         1089.0
# True YES         318.0          109.0
#
# F1: 0.134
#
# Accuracy on class 0: 0.72
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3863.0         1446.0
# True YES         445.0          122.0
#
# F1: 0.114
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         2023.0          825.0
# True YES         326.0          158.0
#
# F1: 0.215
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.33
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          334.0            5.0
# True YES          81.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5960.0           44.0
# True YES         583.0            6.0
#
# F1: 0.019
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6257.0           63.0
# True YES         429.0           15.0
#
# F1: 0.057
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.03
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1254.0            8.0
# True YES         132.0            2.0
#
# F1: 0.028
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         7058.0           84.0
# True YES         654.0           14.0
#
# F1: 0.037
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.02
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1070.0            7.0
# True YES         180.0            1.0
#
# F1: 0.011
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5142.0           51.0
# True YES         440.0            5.0
#
# F1: 0.020
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4551.0           75.0
# True YES         847.0           17.0
#
# F1: 0.036
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.02
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3804.0           37.0
# True YES         420.0            7.0
#
# F1: 0.030
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.02
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5253.0           56.0
# True YES         559.0            8.0
#
# F1: 0.025
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2791.0           57.0
# True YES         462.0           22.0
#
# F1: 0.078
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          226.0          113.0
# True YES          48.0           33.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.67
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3600.0         2404.0
# True YES         430.0          159.0
#
# F1: 0.101
#
# Accuracy on class 0: 0.60
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3869.0         2451.0
# True YES         325.0          119.0
#
# F1: 0.079
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          687.0          575.0
# True YES          95.0           39.0
#
# F1: 0.104
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4370.0         2772.0
# True YES         498.0          170.0
#
# F1: 0.094
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          601.0          476.0
# True YES         126.0           55.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.30
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3110.0         2083.0
# True YES         359.0           86.0
#
# F1: 0.066
#
# Accuracy on class 0: 0.60
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2853.0         1773.0
# True YES         571.0          293.0
#
# F1: 0.200
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.34
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2379.0         1462.0
# True YES         303.0          124.0
#
# F1: 0.123
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3125.0         2184.0
# True YES         431.0          136.0
#
# F1: 0.094
#
# Accuracy on class 0: 0.59
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1856.0          992.0
# True YES         301.0          183.0
#
# F1: 0.221
#
# Accuracy on class 0: 0.65
# Accuracy on class 1: 0.38
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          267.0           72.0
# True YES          45.0           36.0
#
# F1: 0.381
#
# Accuracy on class 0: 0.79
# Accuracy on class 1: 0.44
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4497.0         1507.0
# True YES         320.0          269.0
#
# F1: 0.227
#
# Accuracy on class 0: 0.75
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4890.0         1430.0
# True YES         241.0          203.0
#
# F1: 0.195
#
# Accuracy on class 0: 0.77
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          859.0          403.0
# True YES          79.0           55.0
#
# F1: 0.186
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5313.0         1829.0
# True YES         372.0          296.0
#
# F1: 0.212
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.44
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          770.0          307.0
# True YES          98.0           83.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3808.0         1385.0
# True YES         233.0          212.0
#
# F1: 0.208
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3537.0         1089.0
# True YES         500.0          364.0
#
# F1: 0.314
#
# Accuracy on class 0: 0.76
# Accuracy on class 1: 0.42
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2968.0          873.0
# True YES         242.0          185.0
#
# F1: 0.249
#
# Accuracy on class 0: 0.77
# Accuracy on class 1: 0.43
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3945.0         1364.0
# True YES         304.0          263.0
#
# F1: 0.240
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2228.0          620.0
# True YES         286.0          198.0
#
# F1: 0.304
#
# Accuracy on class 0: 0.78
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          285.0           54.0
# True YES          74.0            7.0
#
# F1: 0.099
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.09
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5552.0          452.0
# True YES         553.0           36.0
#
# F1: 0.067
#
# Accuracy on class 0: 0.92
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5950.0          370.0
# True YES         420.0           24.0
#
# F1: 0.057
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1187.0           75.0
# True YES         123.0           11.0
#
# F1: 0.100
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.08
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6600.0          542.0
# True YES         633.0           35.0
#
# F1: 0.056
#
# Accuracy on class 0: 0.92
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          962.0          115.0
# True YES         173.0            8.0
#
# F1: 0.053
#
# Accuracy on class 0: 0.89
# Accuracy on class 1: 0.04
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4857.0          336.0
# True YES         430.0           15.0
#
# F1: 0.038
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.03
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3979.0          647.0
# True YES         792.0           72.0
#
# F1: 0.091
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.08
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3481.0          360.0
# True YES         395.0           32.0
#
# F1: 0.078
#
# Accuracy on class 0: 0.91
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4929.0          380.0
# True YES         545.0           22.0
#
# F1: 0.045
#
# Accuracy on class 0: 0.93
# Accuracy on class 1: 0.04
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2465.0          383.0
# True YES         418.0           66.0
#
# F1: 0.141
#
# Accuracy on class 0: 0.87
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          209.0          130.0
# True YES          40.0           41.0
#
# F1: 0.325
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3087.0         2917.0
# True YES         296.0          293.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3414.0         2906.0
# True YES         225.0          219.0
#
# F1: 0.123
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          495.0          767.0
# True YES          66.0           68.0
#
# F1: 0.140
#
# Accuracy on class 0: 0.39
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3705.0         3437.0
# True YES         335.0          333.0
#
# F1: 0.150
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          503.0          574.0
# True YES          90.0           91.0
#
# F1: 0.215
#
# Accuracy on class 0: 0.47
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2586.0         2607.0
# True YES         224.0          221.0
#
# F1: 0.135
#
# Accuracy on class 0: 0.50
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2597.0         2029.0
# True YES         434.0          430.0
#
# F1: 0.259
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2139.0         1702.0
# True YES         216.0          211.0
#
# F1: 0.180
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2694.0         2615.0
# True YES         287.0          280.0
#
# F1: 0.162
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1732.0         1116.0
# True YES         241.0          243.0
#
# F1: 0.264
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          223.0          116.0
# True YES          40.0           41.0
#
# F1: 0.345
#
# Accuracy on class 0: 0.66
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3531.0         2473.0
# True YES         306.0          283.0
#
# F1: 0.169
#
# Accuracy on class 0: 0.59
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3845.0         2475.0
# True YES         235.0          209.0
#
# F1: 0.134
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.47
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          618.0          644.0
# True YES          70.0           64.0
#
# F1: 0.152
#
# Accuracy on class 0: 0.49
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4177.0         2965.0
# True YES         349.0          319.0
#
# F1: 0.161
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          586.0          491.0
# True YES          92.0           89.0
#
# F1: 0.234
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2954.0         2239.0
# True YES         225.0          220.0
#
# F1: 0.152
#
# Accuracy on class 0: 0.57
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2847.0         1779.0
# True YES         443.0          421.0
#
# F1: 0.275
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2366.0         1475.0
# True YES         221.0          206.0
#
# F1: 0.195
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3065.0         2244.0
# True YES         290.0          277.0
#
# F1: 0.179
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1852.0          996.0
# True YES         248.0          236.0
#
# F1: 0.275
#
# Accuracy on class 0: 0.65
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          240.0           99.0
# True YES          55.0           26.0
#
# F1: 0.252
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4138.0         1866.0
# True YES         492.0           97.0
#
# F1: 0.076
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4393.0         1927.0
# True YES         374.0           70.0
#
# F1: 0.057
#
# Accuracy on class 0: 0.70
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          837.0          425.0
# True YES         110.0           24.0
#
# F1: 0.082
#
# Accuracy on class 0: 0.66
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4935.0         2207.0
# True YES         550.0          118.0
#
# F1: 0.079
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          702.0          375.0
# True YES         150.0           31.0
#
# F1: 0.106
#
# Accuracy on class 0: 0.65
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3580.0         1613.0
# True YES         394.0           51.0
#
# F1: 0.048
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.11
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3100.0         1526.0
# True YES         664.0          200.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.67
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2641.0         1200.0
# True YES         349.0           78.0
#
# F1: 0.091
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3597.0         1712.0
# True YES         485.0           82.0
#
# F1: 0.069
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1988.0          860.0
# True YES         345.0          139.0
#
# F1: 0.187
#
# Accuracy on class 0: 0.70
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          209.0          130.0
# True YES          40.0           41.0
#
# F1: 0.325
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3087.0         2917.0
# True YES         296.0          293.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3414.0         2906.0
# True YES         225.0          219.0
#
# F1: 0.123
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          495.0          767.0
# True YES          66.0           68.0
#
# F1: 0.140
#
# Accuracy on class 0: 0.39
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3705.0         3437.0
# True YES         335.0          333.0
#
# F1: 0.150
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          503.0          574.0
# True YES          90.0           91.0
#
# F1: 0.215
#
# Accuracy on class 0: 0.47
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2586.0         2607.0
# True YES         224.0          221.0
#
# F1: 0.135
#
# Accuracy on class 0: 0.50
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2597.0         2029.0
# True YES         434.0          430.0
#
# F1: 0.259
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2139.0         1702.0
# True YES         216.0          211.0
#
# F1: 0.180
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2694.0         2615.0
# True YES         287.0          280.0
#
# F1: 0.162
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1732.0         1116.0
# True YES         241.0          243.0
#
# F1: 0.264
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.50

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.heatmap(acc_matrix)
plt.xticks(np.arange(11)+0.5,mice,rotation='vertical')
plt.yticks(np.arange(11)+0.5,mice[::-1],rotation='horizontal')
plt.xlabel('Training Mouse')
plt.ylabel('Testing Mouse')
plt.title('Accuracy')

plt.subplot(122)
sns.heatmap(F1_matrix)
plt.xticks(np.arange(11)+0.5,mice,rotation='vertical')
plt.yticks(np.arange(11)+0.5,mice[::-1],rotation='horizontal')
plt.xlabel('Training Mouse')
plt.ylabel('Testing Mouse')
plt.title('F1')

# %%
data_80.head(2)
# Out:
#    Condition Mouse ID   Session ID  Block Trial  Port Streak  Reward Streak  \
# 0        0.8       K1  11212016_K1         11.0          1.0            1.0
# 1        0.8       K1  11212016_K1         12.0          2.0            2.0
#
#    10_Port  10_Reward  10_ITI  10_trialDuration   ...    2_trialDuration  \
# 0     -1.0        1.0   1.993             0.727   ...              0.524
# 1     -1.0        1.0   1.729             0.894   ...              0.573
#
#    1_Port  1_Reward  1_ITI  1_trialDuration  0_ITI  Decision  Switch  \
# 0    -1.0       1.0  1.303            0.573  1.952       0.0     0.0
# 1    -1.0       1.0  1.952            0.445  2.681       0.0     0.0
#
#    Higher p port  Reward
# 0            1.0     1.0
# 1            1.0     1.0
#
# [2 rows x 51 columns]

# %%
u_switch = np.zeros(len(mice))
u_acc = np.zeros(len(mice))

for i,mouse in enumerate(mice):
    u_switch[i] = data_80[data_80['Mouse ID']== mouse]['Switch'].mean()
    u_acc[i] = data_80[data_80['Mouse ID']== mouse]['Higher p port'].mean()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Higher switch rates anti-correlate with accuracy on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],acc_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean accuracy when used as test mouse')
plt.ylim(0.75,1)
plt.xlim(0,0.22)
plt.title('Testing accuracy vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],acc_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean accuracy when used as train mouse')
plt.ylim(0.75,1)
plt.xlim(0,0.22)
plt.title('Training accuracy vs mean switch rate')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Higher switch rates correlate with F1 score on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],F1_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean F1 when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing F1 vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],F1_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean F1 when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training F1 vs mean switch rate')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Better behavior correlates with accuracy score on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],acc_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean p(high p port)')
plt.ylabel('mean acc when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing Acc vs mean p(high p port)')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],acc_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean p(high p port)')
plt.ylabel('mean acc when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training acc vs mean p(high p port)')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('p(high p port) vs F1 score',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],F1_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('p(high p port)')
plt.ylabel('mean F1 when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing F1 vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],F1_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('p(high p port)')
plt.ylabel('mean F1 when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training F1 vs mean switch rate')

plt.tight_layout()
